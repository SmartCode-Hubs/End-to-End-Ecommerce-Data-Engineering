# %% [markdown]
# # read one CSV file into Bronze

# %%
# Read Customers.csv from the Bronze volume 
customers_df = spark.read
  .option("header", "true")
  .option("inferSchema", "true")
  .csv("/volumes/bronze/Customers.csv")

)
